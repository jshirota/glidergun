# %%
from glidergun import stack

s = stack("esri", (-130, 48, -120, 55))

s, s.project(4326), s.project(3005), s.project(3157), s.project(2955)
# Out:
# (image: 455x513 uint8 | crs: EPSG:3857 WGS 84 / Pseudo-Mercator | count: 3 | rgb: (1, 2, 3) | cell: (2445.984905, 2445.984905) | extent: (-14472892.683628, 6107624.308099, -13359969.551796, 7362414.564428),
#  image: 562x393 float32 | crs: EPSG:4326 WGS 84 | count: 3 | rgb: (1, 2, 3) | cell: (0.017797, 0.017797) | extent: (-130.012207, 48.008606, -120.010295, 55.002826),
#  image: 492x524 float32 | crs: EPSG:3005 NAD83 / BC Albers | count: 3 | rgb: (1, 2, 3) | cell: (1518.305911, 1518.305911) | extent: (699942.314912, 332090.576801, 1446948.823098, 1127682.874137),
#  image: 491x527 float32 | crs: EPSG:3157 NAD83(CSRS) / UTM zone 10N | count: 3 | rgb: (1, 2, 3) | cell: (1518.630189, 1518.630189) | extent: (-22893.168898, 5317298.454157, 722754.253715, 6117616.56356),
#  image: 510x559 float32 | crs: EPSG:2955 NAD83(CSRS) / UTM zone 11N | count: 3 | rgb: (1, 2, 3) | cell: (1523.449513, 1523.449513) | extent: (-469633.096538, 5321241.673235, 307326.154949, 6172849.950845))
